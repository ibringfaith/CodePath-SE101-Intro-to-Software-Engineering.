# %% [markdown]
# <a href="https://colab.research.google.com/github/ibringfaith/CodePath-SE101-Intro-to-Software-Engineering./blob/main/playingwithAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-generation", model="EleutherAI/gpt-neo-125m")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.01k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/526M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/560 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/357 [00:00<?, ?B/s]

# %%
prompt = "I am a student and I like to"
output = pipe(prompt, max_length = 50) # max length makes responses a little bit longer
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
output
# Out:
# [{'generated_text': 'I am a student and I like to study and study. I am a student and I like to study. I am a student and I like to study. I am a student and I like to study. I am a student and I like to'}]

# %%
type(output)
# Out:
# list

# %%
output[0]
# Out:
# {'generated_text': 'I am a student and I like to study and study. I am a student and I like to study. I am a student and I like to study. I am a student and I like to study. I am a student and I like to'}

# %%
type(output[0])
# Out:
# dict

# %%
output[0]['generated_text']
# Out:
# 'I am a student and I like to study and study. I am a student and I like to study. I am a student and I like to study. I am a student and I like to study. I am a student and I like to'

# %%
# !pip install datasets

from datasets import load_dataset

dataset = load_dataset('truthful_qa', 'generation')
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.1/507.1 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.0 MB/s eta 0:00:00
# ...
# Generating validation split:   0%|          | 0/817 [00:00<?, ? examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     validation: Dataset({
#         features: ['type', 'category', 'question', 'best_answer', 'correct_answers', 'incorrect_answers', 'source'],
#         num_rows: 817
#     })
# })

# %%
dataset['validation']['question'][0]
# Out:
# 'What happens to you if you eat watermelon seeds?'

# %%
# takes first question of dataset as prompt into the text generator
# save output to a new variable
first_question = dataset['validation']['question'][0]
response = pipe(first_question, max_length = 50)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
